# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.simplefilter(action='ignore',category='FutureWarning')
warnings.filterwarnings('ignore')
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
data=pd.read_csv("heart.csv")
data
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 1

# %%
data.drop_duplicates(inplace=True)

# %%
sns.boxplot(x="output", y="age", data= data)
# Out:
# <AxesSubplot:xlabel='output', ylabel='age'>

# %%
sns.boxplot(x="output", y="trtbps", data= data)
# Out:
# <AxesSubplot:xlabel='output', ylabel='trtbps'>

# %%
sns.boxplot(x="output", y="chol", data= data)
# Out:
# <AxesSubplot:xlabel='output', ylabel='chol'>

# %%
sns.boxplot(x="output", y="thalachh", data= data)
# Out:
# <AxesSubplot:xlabel='output', ylabel='thalachh'>

# %%
sns.boxplot(x="output", y="oldpeak", data=data)
# Out:
# <AxesSubplot:xlabel='output', ylabel='oldpeak'>

# %%
data=data[data.trtbps<175]
data=data[data.chol<350]
data=data[data.thalachh>110]
data=data[data.oldpeak<3.5]
data
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 5     57    1   0     140   192    0        1       148     0      0.4    1
# 6     56    0   1     140   294    0        0       153     0      1.3    1
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
data.describe()
# Out:
#               age         sex          cp      trtbps        chol         fbs  \
# count  258.000000  258.000000  258.000000  258.000000  258.000000  258.000000
# mean    53.651163    0.689922    1.034884  129.868217  240.596899    0.143411
# std      9.154235    0.463424    1.030066   15.885230   43.314795    0.351173
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     46.000000    0.000000    0.000000  120.000000  209.250000    0.000000
# 50%     54.000000    1.000000    1.000000  130.000000  236.000000    0.000000
# 75%     60.000000    1.000000    2.000000  140.000000  269.000000    0.000000
# max     77.000000    1.000000    3.000000  174.000000  342.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  258.000000  258.000000  258.000000  258.000000  258.000000  258.000000
# mean     0.527132  153.065891    0.290698    0.840698    1.472868    0.643411
# ...

# %%
sns.countplot(x="output", data=data)
# Out:
# <AxesSubplot:xlabel='output', ylabel='count'>

# %%
plt.figure(figsize=(16,10))
sns.countplot(x=data["age"])
plt.xlabel("AGE")
plt.ylabel("COUNT")
plt.show();

# %%
sns.countplot(x='cp', data=data)
# Out:
# <AxesSubplot:xlabel='cp', ylabel='count'>

# %%
sns.countplot(x='fbs', data=data)
# Out:
# <AxesSubplot:xlabel='fbs', ylabel='count'>

# %%
sns.countplot(x='exng', data=data)
# Out:
# <AxesSubplot:xlabel='exng', ylabel='count'>

# %%
sns.countplot(x='restecg', data=data)
# Out:
# <AxesSubplot:xlabel='restecg', ylabel='count'>

# %%
sns.countplot(x='slp', data=data)
# Out:
# <AxesSubplot:xlabel='slp', ylabel='count'>

# %%
sns.countplot(x='caa', data=data)
# Out:
# <AxesSubplot:xlabel='caa', ylabel='count'>

# %%
sns.countplot(x='thall', data=data)
# Out:
# <AxesSubplot:xlabel='thall', ylabel='count'>

# %%
data.corr()
# Out:
#                age       sex        cp    trtbps      chol       fbs  \
# age       1.000000 -0.063202 -0.005307  0.279249  0.157665  0.106401
# sex      -0.063202  1.000000 -0.058765 -0.000815 -0.115773  0.106943
# cp       -0.005307 -0.058765  1.000000  0.099682 -0.071283  0.104441
# trtbps    0.279249 -0.000815  0.099682  1.000000  0.109653  0.141509
# chol      0.157665 -0.115773 -0.071283  0.109653  1.000000  0.029652
# fbs       0.106401  0.106943  0.104441  0.141509  0.029652  1.000000
# restecg  -0.086204 -0.078652  0.060490 -0.110738 -0.182986 -0.075304
# thalachh -0.383216  0.000976  0.226967 -0.049723  0.000928  0.028096
# exng      0.084235  0.133904 -0.370438  0.031164  0.069942  0.030301
# oldpeak   0.229005  0.136563 -0.101891  0.120144 -0.014983  0.052743
# slp      -0.151869 -0.016766  0.062793 -0.080197  0.066077 -0.066084
# caa       0.283689  0.150198 -0.115211  0.067678  0.069613  0.161011
# thall     0.055865  0.248124 -0.184009  0.021681  0.057075 -0.029420
# ...

# %%
sns.heatmap(data.corr(),annot=True, fmt=".1f",linewidth=0.7)
# Out:
# <AxesSubplot:>

# %%
df = pd.get_dummies(data, columns = ['sex', 'cp', 'fbs', 'restecg', 'exng', 'slp', 'caa', 'thall'])
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
standardScaler = StandardScaler()
columns_to_scale = ['age', 'trtbps', 'chol', 'thalachh', 'oldpeak']
df[columns_to_scale] = standardScaler.fit_transform(df[columns_to_scale])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
x=df.drop(['output'],axis=1)
y=df['output']
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size= 0.60, random_state= 0)
LogReg = LogisticRegression()
LogReg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
predicted=LogReg.predict(x_test)
print ("The accuracy of Logistic Regression is : ", accuracy_score(y_test, predicted)*100, "%")
# Out:
# The accuracy of Logistic Regression is :  84.61538461538461 %

# %%
from sklearn.svm import SVC
model = SVC()
model.fit(x_train, y_train)
# Out:
# SVC()

# %%
predicted = model.predict(x_test)
print("The accuracy of SVM is : ", accuracy_score(y_test, predicted)*100, "%")
# Out:
# The accuracy of SVM is :  83.65384615384616 %

# %%
from sklearn.ensemble import RandomForestClassifier
Ranforest = RandomForestClassifier(n_estimators = 50, random_state = 2)  
Ranforest.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=50, random_state=2)

# %%
predicted = Ranforest.predict(x_test)
print("The accuracy of Random Forest is : ", accuracy_score(y_test, predicted)*100, "%")
# Out:
# The accuracy of Random Forest is :  82.6923076923077 %

# %%
from sklearn.tree import DecisionTreeClassifier

DecTree = DecisionTreeClassifier()

DecTree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
predicted = DecTree.predict(x_test)
print("The accuracy of Decision Tree is : ", accuracy_score(y_test, predicted)*100, "%")
# Out:
# The accuracy of Decision Tree is :  76.92307692307693 %
